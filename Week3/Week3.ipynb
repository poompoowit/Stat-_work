# %%
import pandas as pd

# %%
sr = pd.Series([1,3,5,7])
sr
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# dtype: int64

# %%
sr2 = pd.Series([1,3,5,7],index = ['A','B','C','D'])
sr2
# Out:
# A    1
# B    3
# C    5
# D    7
# dtype: int64

# %%
df = pd.read_csv('week3_ex1_data.csv')
df
# Out:
#                                        Title      Genre  \
# 0                    Guardians of the Galaxy     Action
# 1                                 Prometheus  Adventure
# 2                                      Split     Horror
# 3                                       Sing  Animation
# 4                              Suicide Squad     Action
# 5                             The Great Wall     Action
# 6                                 La La Land     Comedy
# 7                                   Mindhorn     Comedy
# 8                         The Lost City of Z     Action
# 9                                 Passengers  Adventure
# 10   Fantastic Beasts and Where to Find Them  Adventure
# 11                            Hidden Figures  Biography
# 12                                 Rogue One     Action
# 13                                     Moana  Animation
# 14                                  Colossal     Action
# 15                   The Secret Life of Pets  Animation
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Director', 'Year', 'Runtime (Minutes)', 'Rating',
#        'Votes'],
#       dtype='object')

# %%
df[df.Rating > 8.5]
# Out:
#                 Title      Genre           Director  Year  Runtime (Minutes)  \
# 36       Interstellar  Adventure  Christopher Nolan  2014                169
# 54    The Dark Knight     Action  Christopher Nolan  2008                152
# 80          Inception     Action  Christopher Nolan  2010                148
# 96      Kimi no na wa  Animation     Makoto Shinkai  2016                106
# 117            Dangal     Action      Nitesh Tiwari  2016                161
# 249  The Intouchables  Biography    Olivier Nakache  2011                112
#
#      Rating    Votes
# 36      8.6  1047747
# 54      9.0  1791916
# 80      8.8  1583625
# 96      8.6    34110
# 117     8.8    48969
# 249     8.6   557965
